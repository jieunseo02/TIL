# %%
import os
# 작업 폴더로 이동
os.chdir('/content/drive/MyDrive/bootcamp/git_hub/TIL')

# %%
# !git config --global user.email "jieun02031@gmail.com"
# !git config --global user.name "jieunseo02"

# %%
# 1. 새로 만든 파일을 깃 장바구니에 담기
# !git add EDA_practice1.ipynb

# 2. 첫 업로드 기념 메시지 남기기
# !git commit -m "feat: Add new EDA practice notebook in TIL folder"

# 3. 깃허브로 쏘아 올리기!
# !git push origin main
# Out:
# [main 53b90b6] feat: Add new EDA practice notebook in TIL folder
#  1 file changed, 1 insertion(+)
#  create mode 100644 EDA_practice1.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.41 KiB | 144.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/jieunseo02/TIL.git
#    f73cdf2..53b90b6  main -> main

# %%
import numpy as np
import pandas as pd
import sklearn.datasets as D

# %%
# 데이터 불러오기
data = pd.read_csv('/Global YouTube Statistics.csv', encoding='latin1')

# %%
# 데이터 확인
data
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
# 데이터 크기 확인하기
print(data.shape)
# Out:
# (995, 28)

# %%
# 데이터 칼럼 확인하기
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
np.random.seed(242)

# %%
feature_index = np.random.choice(len(data.columns))
print(f"피쳐번호: {feature_index}")

feature_name = data.columns[feature_index]
print(f"피쳐이름: {feature_index}")
data[feature_name]
# Out:
# 피쳐번호: 14
# 피쳐이름: 14
# 0      564600.0
# 1           0.0
# 2      337000.0
# 3      493800.0
# 4      455900.0
#          ...
# 990    138100.0
# 991     16200.0
# 992        17.0
# 993       968.0
# 994      6000.0
# Name: lowest_monthly_earnings, Length: 995, dtype: float64
